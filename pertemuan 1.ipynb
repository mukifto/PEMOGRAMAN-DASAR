# %% [markdown]
# <a href="https://colab.research.google.com/github/mukifto/PEMOGRAMAN-DASAR/blob/main/pertemuan%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Mukifto"
umur = 20
jurusan = "rpe"
semester = 3
matakuliah = 'pemograman dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Mukifto
# 20
# rpe
# 3
# pemograman dasar
# False
